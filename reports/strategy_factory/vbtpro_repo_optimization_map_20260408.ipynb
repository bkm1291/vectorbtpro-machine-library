# %% [markdown]
# # Repo Optimization Map For VBT PRO
#
# Purpose:
# - mark exact repo files and functions where VBT PRO should be used
# - separate `use now`, `adapter first`, `research overlay`, and `keep custom/GPU`
# - keep a working map for a long repo-wide optimization pass
#
# Reference note:
# - `/home/benji/trade_scanner2/reports/strategy_factory/vbtpro_repo_blackwell_encyclopedia_20260408.yaml`

# %% [markdown]
# ## Decision Labels
#
# - `already_vbt`: already materially VBT-backed and should be preserved or extended carefully
# - `vbt_adapter_first`: best first move is an adapter over current repo authority
# - `vbt_overlay_research`: good place for non-authoritative mirrored research outputs
# - `vbt_feature_block`: best fit is additive VBT-derived features or labels
# - `keep_custom_or_gpu`: keep current custom or GPU-native implementation as authority
# - `greenfield_vbt_shadow_pipeline_candidate`: only if adapter path tops out and a second pipeline becomes justified

# %%
from pathlib import Path

repo_roots = [
    Path('/home/benji/trade_scanner2/trade_scanner/strategy_factory'),
    Path('/home/benji/trade_scanner2/trade_scanner/equities_llm_lab'),
    Path('/home/benji/trade_scanner2/scripts'),
]

for root in repo_roots:
    files = sorted(root.rglob('*.py'))
    print(root, len(files))

# %% [markdown]
# ## High-Confidence Script Map
#
# ### Already VBT
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/vbt_equities.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/vbtpro_native_runtime.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/vbt_metadata.py`
# - `/home/benji/trade_scanner2/trade_scanner/equities_llm_lab/history.py`
# - `/home/benji/trade_scanner2/trade_scanner/equities_llm_lab/features.py`
#
# ### VBT Adapter First
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/models.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/walk_forward.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/validation_segments.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/splits.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/pipeline.py`
#
# ### VBT Feature Block
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/feature_builders_gpu.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/semantic_lane2_coarse_medium_feature_discovery.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/labels.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/datasets.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/semantic_lane2_runtime_filters.py`
#
# ### VBT Overlay Research
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/ranking.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/evaluation.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/strategy_research_reports.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/equivalence_reports.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/per_family_holdout.py`
#
# ### Keep Custom Or GPU Authority
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/gpu_executor.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/preprocessing_gpu.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/model_catalog.py`
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/blackwell_ensemble/stacker.py`

# %% [markdown]
# ## Priority Functions To Mark
#
# - `models.py::_train_valid_mask` -> `vbt_adapter_first`
# - `walk_forward.py::_split_dates` -> `vbt_adapter_first`
# - `blackwell_ensemble/splits.py::build_split_plan` -> `vbt_adapter_first`
# - `blackwell_ensemble/feature_builders_gpu.py::add_v1_daily_features` -> `vbt_feature_block`
# - `labels.py::label_candidate_dataset` -> `vbt_feature_block`
# - `blackwell_ensemble/ranking.py::rank_predictions` -> `vbt_overlay_research`
# - `blackwell_ensemble/evaluation.py::portfolio_metrics` -> `vbt_overlay_research`
# - `vbtpro_native_runtime.py::run_native_signal_portfolio` -> `already_vbt`
# - `vbtpro_native_runtime.py::run_native_order_func_portfolio` -> `already_vbt`
# - `gpu_executor.py::fit_gpu_base_models_development_oos` -> `keep_custom_or_gpu`

# %% [markdown]
# ## Greenfield Shadow Pipeline Track
#
# Use only if adapter/overlay path tops out.
#
# Candidate home:
# - `/home/benji/trade_scanner2/trade_scanner/strategy_factory/vbt_ml_research/`
#
# Principles:
# - keep current repo authority intact
# - use current pipeline as semantic map only
# - build a second end-to-end VBT-native research lane for comparison
# - do not merge it into mainline before split, artifact, and holdout parity exist

# %%
optimization_buckets = {
    'already_vbt': [
        'trade_scanner/strategy_factory/vbt_equities.py',
        'trade_scanner/strategy_factory/vbtpro_native_runtime.py',
        'trade_scanner/strategy_factory/vbt_metadata.py',
        'trade_scanner/equities_llm_lab/history.py',
    ],
    'vbt_adapter_first': [
        'trade_scanner/strategy_factory/models.py',
        'trade_scanner/strategy_factory/walk_forward.py',
        'trade_scanner/strategy_factory/validation_segments.py',
        'trade_scanner/strategy_factory/blackwell_ensemble/splits.py',
        'trade_scanner/strategy_factory/pipeline.py',
    ],
    'vbt_feature_block': [
        'trade_scanner/strategy_factory/blackwell_ensemble/feature_builders_gpu.py',
        'trade_scanner/strategy_factory/semantic_lane2_coarse_medium_feature_discovery.py',
        'trade_scanner/strategy_factory/labels.py',
        'trade_scanner/strategy_factory/datasets.py',
    ],
    'vbt_overlay_research': [
        'trade_scanner/strategy_factory/blackwell_ensemble/ranking.py',
        'trade_scanner/strategy_factory/blackwell_ensemble/evaluation.py',
        'trade_scanner/strategy_factory/strategy_research_reports.py',
        'trade_scanner/strategy_factory/equivalence_reports.py',
    ],
    'keep_custom_or_gpu': [
        'trade_scanner/strategy_factory/blackwell_ensemble/gpu_executor.py',
        'trade_scanner/strategy_factory/blackwell_ensemble/preprocessing_gpu.py',
        'trade_scanner/strategy_factory/blackwell_ensemble/model_catalog.py',
        'trade_scanner/strategy_factory/blackwell_ensemble/stacker.py',
    ],
}

print(json.dumps(optimization_buckets, indent=2))

# %% [markdown]
# ## Next Expansion
#
# This notebook is the optimization index. The next pass should expand it into:
# - script-by-script classification across all `strategy_factory`, `equities_llm_lab`, and `scripts`
# - exact function-level notes for each major file
# - replacement candidates vs adapter candidates vs no-go GPU/custom zones
# - links back to the encyclopedia note and the eventual brainstorm ideas note
